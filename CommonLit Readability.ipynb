# %% [markdown]
# https://www.kaggle.com/c/commonlitreadabilityprize/overview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle 
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# !kaggle competitions download -c commonlitreadabilityprize
! unzip train.csv.zip -d train
# Out:
#      <input type="file" id="files-76816072-4b7c-4b02-b656-a203712143dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76816072-4b7c-4b02-b656-a203712143dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading test.csv to /content
#   0% 0.00/6.79k [00:00<?, ?B/s]
# 100% 6.79k/6.79k [00:00<00:00, 12.6MB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/108 [00:00<?, ?B/s]
# 100% 108/108 [00:00<00:00, 88.7kB/s]
# Downloading train.csv.zip to /content
#   0% 0.00/1.13M [00:00<?, ?B/s]
# 100% 1.13M/1.13M [00:00<00:00, 75.8MB/s]
# Archive:  train.csv.zip
#   inflating: train/train.csv

# %%
train_path = "/content/train/train.csv"
test_path = "/content/test.csv"
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
train
# Out:
#              id  ... standard_error
# 0     c12129c31  ...       0.464009
# 1     85aa80a4c  ...       0.480805
# 2     b69ac6792  ...       0.476676
# 3     dd1000b26  ...       0.450007
# 4     37c1b32fb  ...       0.510845
# ...         ...  ...            ...
# 2829  25ca8f498  ...       0.646900
# 2830  2c26db523  ...       0.535648
# 2831  cd19e2350  ...       0.483866
# 2832  15e2e9e7a  ...       0.514128
# 2833  5b990ba77  ...       0.512379
#
# [2834 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
X = train['excerpt']
y= train['target']

# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification

checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=536063208.0, style=ProgressStyle(descri…
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
inputs = []
for x in X:
  te = np.array(tokenizer(x,padding=True,truncation=True,return_tensors="tf")['input_ids'])
  inputs.append(te)

# %%
model.predict(inputs)
